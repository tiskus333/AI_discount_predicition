# %%
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_json("data2/normal_vpm.json",orient="records",lines=True)

# %%
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
g1 = sns.countplot(data=df,x='is_purchased',hue='curr_disc')

# %%
print(f'Procent zakonczonych zakupem: {len(df[df.is_purchased == 1])/len(df):.2%}')
# Out:
# Procent zakonczonych zakupem: 18.05%
